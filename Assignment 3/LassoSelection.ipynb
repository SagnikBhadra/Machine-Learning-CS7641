# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import explained_variance_score, silhouette_score, accuracy_score, homogeneity_score, f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV


import pandas as pd
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, validation_curve, GridSearchCV, train_test_split
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import timeit

import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)


from util import evaluate_data, graph_LC, graph_C, normalize_data, create_stratified_data, prepare_data, preprocess_ufc_data

# %%
def separate_data_label(dataset, label):
    X = dataset.drop(label, 1).copy().values
    Y = dataset[label].copy().values
    x_df = dataset.drop(label,1)
    
    return X, Y, x_df
    
def normalize(X, x_df):
    normalize_factor = preprocessing.MinMaxScaler()
    X = normalize_factor.fit_transform(X)
    x_df = pd.DataFrame(X, columns=x_df.columns)
    
    return X, x_df

def run_gridsearch(values, adaBoost, input_train_set, output_train_set, cross_validation_splitter, weighting):
    grid_suggestion = GridSearchCV(adaBoost, values, cv=cross_validation_splitter, scoring=weighting)
    grid_suggestion.fit(input_train_set, output_train_set)
    print(grid_suggestion.best_estimator_, grid_suggestion.best_score_)
    
    return grid_suggestion

def run_validation_curve(learner, input_train_set, output_train_set, hyperparameter_values, hyperparameter_values2, weighting, hyperparameter, inverse_x, cross_validation_splitter, title):
    result_train, result_test = validation_curve(
        learner, input_train_set, output_train_set, param_name=hyperparameter, param_range=hyperparameter_values,
        scoring=weighting, verbose=1, cv=cross_validation_splitter, n_jobs=-1
    )
    print(result_train.mean(axis=1), result_test.mean(axis=1))
    graph_C(result_train.mean(axis=1), result_test.mean(axis=1), hyperparameter_values2, title=title, inverse_x=inverse_x)
    
    return result_train, result_test

def compute_score(input_train_set, output_train_set, AdaBoost_Learner, mean, title):
    result = evaluate_data(input_train_set, output_train_set, AdaBoost_Learner, f1_score, average=mean)
    graph_LC(result[0], result[1], result[2], title=title)
    
    
def plot_metric(dictSilohuetteScore, dictHomogeneityScore, yLabel, title):
    plt.figure()
    plt.title(title)
    plt.plot(list(dictSilohuetteScore.keys()), list(dictSilohuetteScore.values()), 'r', label="Silhouette")
    plt.plot(list(dictHomogeneityScore.keys()), list(dictHomogeneityScore.values()), 'g', label="Homogeneity")
    plt.legend()
    plt.xlabel("Number of cluster")
    plt.ylabel(yLabel)
    plt.savefig(title)
    plt.show()

    
def silh_homog_scores(numOfClusters, X, Y, isWine, title):
    dictSilohuetteScore = {}
    dictHomogeneityScore = {}
    for i in numOfClusters:
        cKMeansAlgorithm = KMeans(n_clusters=i, n_init=50, max_iter=1000, random_state=42).fit(X)
        if isWine:
            dictHomogeneityScore[i] = homogeneity_score(Y, (cKMeansAlgorithm.labels_+1))
        else:
            dictHomogeneityScore[i] = homogeneity_score(Y, cKMeansAlgorithm.labels_)
        dictSilohuetteScore[i] = silhouette_score(X, cKMeansAlgorithm.labels_, metric='euclidean')
        print("Number of Clusters = {}, Silhouette Score = {}".format(i, dictSilohuetteScore[i]))
        print("Number of Clusters = {}, Homogeneity Score = {}".format(i, dictHomogeneityScore[i]))
        
    plot_metric(dictSilohuetteScore, dictHomogeneityScore, "Score", title)
    
def expectation_maximization(numOfClusters, X, Y, title):
    dictSilohuetteScore = {}
    dictHomogeneityScore = {}
    GaussianMixScore = {}
    for i in numOfClusters:
        cExpectationMaximization = GaussianMixture(n_components=i, max_iter=100, random_state=42).fit(X)
        target = cExpectationMaximization.predict(X)
        dictSilohuetteScore[i] = silhouette_score(X, target, metric='euclidean')
        dictHomogeneityScore[i] = homogeneity_score(Y, target)
        GaussianMixScore[i] = cExpectationMaximization.score(X)

        print(f"Number of Clusters = {i}, The Silhouette Coefficient is {dictSilohuetteScore[i]}")
        print("Number of Clusters = {}, Homogeneity Score = {}".format(i, dictHomogeneityScore[i]))
        print("Number of Clusters = {}, The log_likelihood score is {}".format(i, GaussianMixScore[i]))

    
    plot_metric(dictSilohuetteScore, dictHomogeneityScore, "Score", title)
    

if __name__ == "__main__":
    wine_label = "class"
    ufc_label = "Winner"
    mean="weighted"
    cross_validation_splitter = 10
    weighting = 'f1_weighted'
    hyperparameter = "hidden_layer_sizes"
    np.random.seed(42)
    
    
    wine_dataset = pd.read_csv("wine_dataset.csv")
    ufc_dataset = pd.read_csv("ufc_data.csv")
    
    #Data preparation
    
    ufc_dataset = preprocess_ufc_data(ufc_dataset)
    
    wine_X, wine_Y, wine_x_df = separate_data_label(wine_dataset, wine_label)
    ufc_X, ufc_Y, ufc_x_df = separate_data_label(ufc_dataset, ufc_label)
    
    #Normalization
    
    wine_X, wine_x_df = normalize(wine_X, wine_x_df)
    ufc_X, ufc_x_df = normalize(ufc_X, ufc_x_df)
    
    
    
    #UFC
    
    cReducedAlgorithm = SelectFromModel(LassoCV(max_iter=10000), max_features=40)
    cReducedAlgorithm.fit(ufc_X, ufc_Y)
    newLabelsUFC = cReducedAlgorithm.transform(ufc_X)
    
    #Silhuette and homogenity scores
    
    silh_homog_scores(range(2, 31, 1), newLabelsUFC, ufc_Y, False, "Silhouette Score for UFC dataset - SelectKBest")
    
    
    #Expectation Maximization
    
    expectation_maximization(range(2, 31, 1), ufc_X, ufc_Y, "Homogenenity Score for UFC dataset - SelectKBest")
    
    
    #Wine
    
    dims_wine = list(range(1,14,1))

    cReducedAlgorithm = SelectFromModel(LassoCV(max_iter=10000), max_features=5)
    cReducedAlgorithm.fit(wine_X, wine_Y)
    newLabelsWine = cReducedAlgorithm.transform(wine_X)
    
    #Silhuette and homogenity scores
    
    silh_homog_scores(range(2, 31, 1), newLabelsWine, wine_Y, True, "Silhouette Score for Wine dataset - SelectKBest")
    
    
    #Expectation Maximization
    
    expectation_maximization(range(2, 31, 1), wine_X, wine_Y, "Homogenenity Score for Wine dataset - SelectKBest")
    
    #Neural Net
    
    #KMeans

    NN_Learner = MLPClassifier()
    NN_Learner.fit(newLabelsWine, wine_Y)

    train_y_hat_wine = NN_Learner.predict(newLabelsWine)
    errorMetric = accuracy_score(wine_Y, train_y_hat_wine)
    print(errorMetric)
    print(classification_report(wine_Y, train_y_hat_wine))

    result = cross_val_score(NN_Learner, newLabelsWine, wine_Y, scoring=weighting, cv=cross_validation_splitter)
    print(result, result.mean())

    input_train_set, input_test_set, output_train_set, output_test_set = train_test_split(newLabelsWine, wine_Y, test_size=0.33, random_state=42, stratify=wine_Y)

    compute_score(input_train_set, output_train_set, NN_Learner, mean, "Default Neural Net on SelectKBest reduced dataset")

    #Best net 

    optimized_NN = MLPClassifier(alpha=0.1, hidden_layer_sizes=(60, 60), learning_rate='invscaling')

    compute_score(input_train_set, output_train_set, optimized_NN, mean, "Optimized Neural Net on SelectKBest reduced dataset")

    hyperparameter_values2 = [60, 80, 100]
    hyperparameter_values = [(60,60), (80,80), (100,100)]
    
    result_train, result_test = run_validation_curve(optimized_NN, input_train_set, output_train_set, hyperparameter_values, hyperparameter_values2, weighting, hyperparameter, True, 5, "Hyperparameter Tuning on Neural Net on SelectKBest reduced dataset")

    print('EM')
    start = timeit.default_timer()
    
    optimized_NN = MLPClassifier(alpha=0.1, hidden_layer_sizes=(100, 100), learning_rate='invscaling')

    compute_score(input_train_set, output_train_set, optimized_NN, mean, "Best Neural Net on SelectKBest reduced dataset")

    stop = timeit.default_timer()
    print('SelectKBest Time: ', stop - start) 

    optimized_NN.fit(input_train_set, output_train_set)
    test_y_hat = optimized_NN.predict(input_test_set)
    print(classification_report(output_test_set, test_y_hat, digits=5))
    print(confusion_matrix(output_test_set, test_y_hat))
# Out:
# Number of Clusters = 2, Silhouette Score = 0.16234100717362587
# Number of Clusters = 2, Homogeneity Score = 0.00043524792991972834
# Number of Clusters = 3, Silhouette Score = 0.16753312019383212
# Number of Clusters = 3, Homogeneity Score = 0.0005998379853170648
# Number of Clusters = 4, Silhouette Score = 0.18090598828347584
# Number of Clusters = 4, Homogeneity Score = 0.0009908750254041605
# Number of Clusters = 5, Silhouette Score = 0.18090732487479716
# Number of Clusters = 5, Homogeneity Score = 0.0016766357460172882
# Number of Clusters = 6, Silhouette Score = 0.18273145859668355
# Number of Clusters = 6, Homogeneity Score = 0.0021055861311315496
# Number of Clusters = 7, Silhouette Score = 0.17970027600316144
# Number of Clusters = 7, Homogeneity Score = 0.0030645871881225793
# Number of Clusters = 8, Silhouette Score = 0.1929494997072845
# Number of Clusters = 8, Homogeneity Score = 0.003477869014460328
# Number of Clusters = 9, Silhouette Score = 0.194554717496158
# Number of Clusters = 9, Homogeneity Score = 0.010641620415974211
# Number of Clusters = 10, Silhouette Score = 0.20553124647232865
# Number of Clusters = 10, Homogeneity Score = 0.012001320112385373
# Number of Clusters = 11, Silhouette Score = 0.20831065153353293
# Number of Clusters = 11, Homogeneity Score = 0.011845026993904375
# Number of Clusters = 12, Silhouette Score = 0.16072198171091848
# Number of Clusters = 12, Homogeneity Score = 0.014052662951718682
# Number of Clusters = 13, Silhouette Score = 0.1707738184996721
# Number of Clusters = 13, Homogeneity Score = 0.014396828922788074
# Number of Clusters = 14, Silhouette Score = 0.17679502277689094
# Number of Clusters = 14, Homogeneity Score = 0.014778548384426571
# Number of Clusters = 15, Silhouette Score = 0.18340059922541374
# Number of Clusters = 15, Homogeneity Score = 0.014909090840919525
# Number of Clusters = 16, Silhouette Score = 0.18114082462617118
# Number of Clusters = 16, Homogeneity Score = 0.020333313207419632
# Number of Clusters = 17, Silhouette Score = 0.1837301637773079
# Number of Clusters = 17, Homogeneity Score = 0.01482534482494931
# Number of Clusters = 18, Silhouette Score = 0.18265688416498282
# Number of Clusters = 18, Homogeneity Score = 0.014173134960637197
# Number of Clusters = 19, Silhouette Score = 0.15805902751074496
# Number of Clusters = 19, Homogeneity Score = 0.01741713920827889
# Number of Clusters = 20, Silhouette Score = 0.1814636860726712
# Number of Clusters = 20, Homogeneity Score = 0.014192225144042593
# Number of Clusters = 21, Silhouette Score = 0.19033943987616733
# Number of Clusters = 21, Homogeneity Score = 0.013812340505253842
# Number of Clusters = 22, Silhouette Score = 0.17359068563094554
# Number of Clusters = 22, Homogeneity Score = 0.02169168410080582
# Number of Clusters = 23, Silhouette Score = 0.1745130176084676
# Number of Clusters = 23, Homogeneity Score = 0.019741704262045117
# Number of Clusters = 24, Silhouette Score = 0.17097578778451303
# Number of Clusters = 24, Homogeneity Score = 0.021578399731837106
# Number of Clusters = 25, Silhouette Score = 0.15958937463148773
# Number of Clusters = 25, Homogeneity Score = 0.025531493001115468
# Number of Clusters = 26, Silhouette Score = 0.1599345778318289
# Number of Clusters = 26, Homogeneity Score = 0.02303898015597666
# Number of Clusters = 27, Silhouette Score = 0.1562818314202991
# Number of Clusters = 27, Homogeneity Score = 0.01934019237046274
# Number of Clusters = 28, Silhouette Score = 0.18162788105920386
# Number of Clusters = 28, Homogeneity Score = 0.01809533151070196
# Number of Clusters = 29, Silhouette Score = 0.1586603023971344
# Number of Clusters = 29, Homogeneity Score = 0.029105190762181404
# Number of Clusters = 30, Silhouette Score = 0.16302450188926074
# Number of Clusters = 30, Homogeneity Score = 0.021329371076692003
# Number of Clusters = 2, The Silhouette Coefficient is 0.047468793914380435
# Number of Clusters = 2, Homogeneity Score = 8.973115053065334e-05
# Number of Clusters = 2, The log_likelihood score is 312.223817216252
# Number of Clusters = 3, The Silhouette Coefficient is 0.06854189622887509
# Number of Clusters = 3, Homogeneity Score = 0.008709912549001298
# Number of Clusters = 3, The log_likelihood score is 348.22639219490884
# Number of Clusters = 4, The Silhouette Coefficient is 0.07199709910492134
# Number of Clusters = 4, Homogeneity Score = 0.005534278584783331
# Number of Clusters = 4, The log_likelihood score is 360.21912209504546
# Number of Clusters = 5, The Silhouette Coefficient is 0.09166330474326631
# Number of Clusters = 5, Homogeneity Score = 0.006388253518342011
# Number of Clusters = 5, The log_likelihood score is 348.9235687764609
# Number of Clusters = 6, The Silhouette Coefficient is 0.0841214027131116
# Number of Clusters = 6, Homogeneity Score = 0.005702839856550381
# Number of Clusters = 6, The log_likelihood score is 356.40439492076496
# Number of Clusters = 7, The Silhouette Coefficient is 0.08452269413074122
# Number of Clusters = 7, Homogeneity Score = 0.007844847419361374
# Number of Clusters = 7, The log_likelihood score is 366.65570696555267
# Number of Clusters = 8, The Silhouette Coefficient is 0.0937622269739867
# Number of Clusters = 8, Homogeneity Score = 0.008177392431414755
# Number of Clusters = 8, The log_likelihood score is 372.40817939822693
# Number of Clusters = 9, The Silhouette Coefficient is 0.10268420114698266
# Number of Clusters = 9, Homogeneity Score = 0.008344296635915559
# Number of Clusters = 9, The log_likelihood score is 377.3983126450341
# Number of Clusters = 10, The Silhouette Coefficient is 0.10424207831681342
# Number of Clusters = 10, Homogeneity Score = 0.008969083148461687
# Number of Clusters = 10, The log_likelihood score is 382.19278780348236
# Number of Clusters = 11, The Silhouette Coefficient is 0.11018680629426458
# Number of Clusters = 11, Homogeneity Score = 0.007927815261761487
# Number of Clusters = 11, The log_likelihood score is 389.4895441957414
# Number of Clusters = 12, The Silhouette Coefficient is 0.12541241352979055
# Number of Clusters = 12, Homogeneity Score = 0.009932346530345335
# Number of Clusters = 12, The log_likelihood score is 393.2466251597909
# Number of Clusters = 13, The Silhouette Coefficient is 0.12932799505419934
# Number of Clusters = 13, Homogeneity Score = 0.00903818004403085
# Number of Clusters = 13, The log_likelihood score is 398.0154703778136
# Number of Clusters = 14, The Silhouette Coefficient is 0.13430279655923114
# Number of Clusters = 14, Homogeneity Score = 0.009145854897635804
# Number of Clusters = 14, The log_likelihood score is 404.16751130410574
# Number of Clusters = 15, The Silhouette Coefficient is 0.13538899243645522
# Number of Clusters = 15, Homogeneity Score = 0.008530941817033958
# Number of Clusters = 15, The log_likelihood score is 411.5074712337117
# Number of Clusters = 16, The Silhouette Coefficient is 0.1381358219477238
# Number of Clusters = 16, Homogeneity Score = 0.015459189993581278
# Number of Clusters = 16, The log_likelihood score is 417.8695193982672
# Number of Clusters = 17, The Silhouette Coefficient is 0.1244958449329905
# Number of Clusters = 17, Homogeneity Score = 0.013499601421129728
# Number of Clusters = 17, The log_likelihood score is 415.86278859988636
# Number of Clusters = 18, The Silhouette Coefficient is 0.12425595105330194
# Number of Clusters = 18, Homogeneity Score = 0.02255222387525596
# Number of Clusters = 18, The log_likelihood score is 423.0102923379823
# Number of Clusters = 19, The Silhouette Coefficient is 0.12960925003189946
# Number of Clusters = 19, Homogeneity Score = 0.0232510405903363
# Number of Clusters = 19, The log_likelihood score is 425.74143014062753
# Number of Clusters = 20, The Silhouette Coefficient is 0.11504606532218649
# Number of Clusters = 20, Homogeneity Score = 0.027330411252706046
# Number of Clusters = 20, The log_likelihood score is 429.26028388706845
# Number of Clusters = 21, The Silhouette Coefficient is 0.11059138601101105
# Number of Clusters = 21, Homogeneity Score = 0.01906025358964635
# Number of Clusters = 21, The log_likelihood score is 429.5360864227134
# Number of Clusters = 22, The Silhouette Coefficient is 0.11631912728529324
# Number of Clusters = 22, Homogeneity Score = 0.020329144997486375
# Number of Clusters = 22, The log_likelihood score is 435.00969576648123
# Number of Clusters = 23, The Silhouette Coefficient is 0.12014239946285754
# Number of Clusters = 23, Homogeneity Score = 0.026003241893055605
# Number of Clusters = 23, The log_likelihood score is 441.9324010686722
# Number of Clusters = 24, The Silhouette Coefficient is 0.11878629987249056
# Number of Clusters = 24, Homogeneity Score = 0.02686577391391439
# Number of Clusters = 24, The log_likelihood score is 446.1638203904748
# Number of Clusters = 25, The Silhouette Coefficient is 0.11517993305948328
# Number of Clusters = 25, Homogeneity Score = 0.02440771453648719
# Number of Clusters = 25, The log_likelihood score is 451.8753867522794
# Number of Clusters = 26, The Silhouette Coefficient is 0.11837685610126211
# Number of Clusters = 26, Homogeneity Score = 0.02632290406143929
# Number of Clusters = 26, The log_likelihood score is 457.79106527674287
# Number of Clusters = 27, The Silhouette Coefficient is 0.12179403707559293
# Number of Clusters = 27, Homogeneity Score = 0.02593279804094758
# Number of Clusters = 27, The log_likelihood score is 463.0997498318051
# Number of Clusters = 28, The Silhouette Coefficient is 0.12417741319560477
# Number of Clusters = 28, Homogeneity Score = 0.026289328197267786
# Number of Clusters = 28, The log_likelihood score is 469.71010632176046
# Number of Clusters = 29, The Silhouette Coefficient is 0.11764096546454403
# Number of Clusters = 29, Homogeneity Score = 0.023116419331556726
# Number of Clusters = 29, The log_likelihood score is 472.43136649297094
# Number of Clusters = 30, The Silhouette Coefficient is 0.11042860127844518
# Number of Clusters = 30, Homogeneity Score = 0.023849044811862303
# Number of Clusters = 30, The log_likelihood score is 477.5248723368921
# Number of Clusters = 2, Silhouette Score = 0.2944214721729675
# Number of Clusters = 2, Homogeneity Score = 0.2874191656823064
# Number of Clusters = 3, Silhouette Score = 0.2894936683398292
# Number of Clusters = 3, Homogeneity Score = 0.6039618118232019
# Number of Clusters = 4, Silhouette Score = 0.2558428811383586
# Number of Clusters = 4, Homogeneity Score = 0.559864618743267
# Number of Clusters = 5, Silhouette Score = 0.23272082123779572
# Number of Clusters = 5, Homogeneity Score = 0.5509145245684262
# Number of Clusters = 6, Silhouette Score = 0.21991095120945292
# Number of Clusters = 6, Homogeneity Score = 0.5665613005963112
# Number of Clusters = 7, Silhouette Score = 0.19769845959278232
# Number of Clusters = 7, Homogeneity Score = 0.6039567494489042
# Number of Clusters = 8, Silhouette Score = 0.20130576853597684
# Number of Clusters = 8, Homogeneity Score = 0.6023063937660985
# Number of Clusters = 9, Silhouette Score = 0.19903294734539992
# Number of Clusters = 9, Homogeneity Score = 0.6124570820742181
# Number of Clusters = 10, Silhouette Score = 0.20457281751001977
# Number of Clusters = 10, Homogeneity Score = 0.6199001274979409
# Number of Clusters = 11, Silhouette Score = 0.2064062815998901
# Number of Clusters = 11, Homogeneity Score = 0.6197416652247957
# Number of Clusters = 12, Silhouette Score = 0.20453061522491783
# Number of Clusters = 12, Homogeneity Score = 0.6308235331646898
# Number of Clusters = 13, Silhouette Score = 0.19875695135039378
# Number of Clusters = 13, Homogeneity Score = 0.632075812217415
# Number of Clusters = 14, Silhouette Score = 0.18788959864769555
# Number of Clusters = 14, Homogeneity Score = 0.6405580468180166
# Number of Clusters = 15, Silhouette Score = 0.18659140354313125
# Number of Clusters = 15, Homogeneity Score = 0.6323043562539893
# Number of Clusters = 16, Silhouette Score = 0.18505555211858488
# Number of Clusters = 16, Homogeneity Score = 0.6339219959569137
# Number of Clusters = 17, Silhouette Score = 0.18151790022548725
# Number of Clusters = 17, Homogeneity Score = 0.6430052543067736
# Number of Clusters = 18, Silhouette Score = 0.1890431736813057
# Number of Clusters = 18, Homogeneity Score = 0.6475259904625714
# Number of Clusters = 19, Silhouette Score = 0.18119883314046914
# Number of Clusters = 19, Homogeneity Score = 0.6452648096098461
# Number of Clusters = 20, Silhouette Score = 0.1797721510084592
# Number of Clusters = 20, Homogeneity Score = 0.6499277571287576
# Number of Clusters = 21, Silhouette Score = 0.181330821592476
# Number of Clusters = 21, Homogeneity Score = 0.6487730708178193
# Number of Clusters = 22, Silhouette Score = 0.18059946956218292
# Number of Clusters = 22, Homogeneity Score = 0.6556432638356519
# Number of Clusters = 23, Silhouette Score = 0.17853007557430728
# Number of Clusters = 23, Homogeneity Score = 0.6508051232659505
# Number of Clusters = 24, Silhouette Score = 0.17495775861693225
# Number of Clusters = 24, Homogeneity Score = 0.6627133675331609
# Number of Clusters = 25, Silhouette Score = 0.17590513007452055
# Number of Clusters = 25, Homogeneity Score = 0.6611102968043321
# Number of Clusters = 26, Silhouette Score = 0.17808895831415344
# Number of Clusters = 26, Homogeneity Score = 0.6726238032068821
# Number of Clusters = 27, Silhouette Score = 0.17608457304292946
# Number of Clusters = 27, Homogeneity Score = 0.6673134129940497
# Number of Clusters = 28, Silhouette Score = 0.17350127434968476
# Number of Clusters = 28, Homogeneity Score = 0.6799644849329818
# Number of Clusters = 29, Silhouette Score = 0.17632747591131942
# Number of Clusters = 29, Homogeneity Score = 0.6870460805481132
# Number of Clusters = 30, Silhouette Score = 0.1694423582978924
# Number of Clusters = 30, Homogeneity Score = 0.6706882790697225
# Number of Clusters = 2, The Silhouette Coefficient is 0.16455334570824817
# Number of Clusters = 2, Homogeneity Score = 0.3147064634531698
# Number of Clusters = 2, The log_likelihood score is 4.757311068514165
# Number of Clusters = 3, The Silhouette Coefficient is 0.1717713766567331
# Number of Clusters = 3, Homogeneity Score = 0.6055861307653634
# Number of Clusters = 3, The log_likelihood score is 4.99350449240883
# Number of Clusters = 4, The Silhouette Coefficient is 0.12846311028785698
# Number of Clusters = 4, Homogeneity Score = 0.5682255641213504
# Number of Clusters = 4, The log_likelihood score is 5.317730957986503
# Number of Clusters = 5, The Silhouette Coefficient is 0.08545839859279354
# Number of Clusters = 5, Homogeneity Score = 0.5750999531704672
# Number of Clusters = 5, The log_likelihood score is 5.486225048685634
# Number of Clusters = 6, The Silhouette Coefficient is 0.06427597005334387
# Number of Clusters = 6, Homogeneity Score = 0.6867832650208452
# Number of Clusters = 6, The log_likelihood score is 5.538903642503948
# Number of Clusters = 7, The Silhouette Coefficient is 0.04852814884554036
# Number of Clusters = 7, Homogeneity Score = 0.663224698414316
# Number of Clusters = 7, The log_likelihood score is 5.598410654871386
# Number of Clusters = 8, The Silhouette Coefficient is 0.027945901692480953
# Number of Clusters = 8, Homogeneity Score = 0.6626571537046464
# Number of Clusters = 8, The log_likelihood score is 5.662237346600801
# Number of Clusters = 9, The Silhouette Coefficient is 0.04777004576112149
# Number of Clusters = 9, Homogeneity Score = 0.6617631594687207
# Number of Clusters = 9, The log_likelihood score is 5.757149142006517
# Number of Clusters = 10, The Silhouette Coefficient is 0.019863619137079725
# Number of Clusters = 10, Homogeneity Score = 0.6813669613943402
# Number of Clusters = 10, The log_likelihood score is 5.800762520550633
# Number of Clusters = 11, The Silhouette Coefficient is 0.032355392884110816
# Number of Clusters = 11, Homogeneity Score = 0.6575374128444893
# Number of Clusters = 11, The log_likelihood score is 5.842267563488342
# Number of Clusters = 12, The Silhouette Coefficient is 0.008726919810505487
# Number of Clusters = 12, Homogeneity Score = 0.6866430984308034
# Number of Clusters = 12, The log_likelihood score is 5.887034059682757
# Number of Clusters = 13, The Silhouette Coefficient is 0.005913410343312977
# Number of Clusters = 13, Homogeneity Score = 0.6743276401021485
# Number of Clusters = 13, The log_likelihood score is 5.914058913481641
# Number of Clusters = 14, The Silhouette Coefficient is 0.007315828647223847
# Number of Clusters = 14, Homogeneity Score = 0.6775205513616387
# Number of Clusters = 14, The log_likelihood score is 5.945671769070492
# Number of Clusters = 15, The Silhouette Coefficient is 0.0095678907434602
# Number of Clusters = 15, Homogeneity Score = 0.6799440670503589
# Number of Clusters = 15, The log_likelihood score is 6.000497003375844
# Number of Clusters = 16, The Silhouette Coefficient is -0.0015579683912283328
# Number of Clusters = 16, Homogeneity Score = 0.7007330933081154
# Number of Clusters = 16, The log_likelihood score is 6.037966858088838
# Number of Clusters = 17, The Silhouette Coefficient is -0.010440650742526859
# Number of Clusters = 17, Homogeneity Score = 0.7022313057231613
# Number of Clusters = 17, The log_likelihood score is 6.073796741229121
# Number of Clusters = 18, The Silhouette Coefficient is -0.003902108957194912
# Number of Clusters = 18, Homogeneity Score = 0.6857539117644185
# Number of Clusters = 18, The log_likelihood score is 6.090857510633813
# Number of Clusters = 19, The Silhouette Coefficient is -0.0069950022593993156
# Number of Clusters = 19, Homogeneity Score = 0.6974685795595887
# Number of Clusters = 19, The log_likelihood score is 6.130943869167345
# Number of Clusters = 20, The Silhouette Coefficient is -0.002973021705588064
# Number of Clusters = 20, Homogeneity Score = 0.6978088317650845
# Number of Clusters = 20, The log_likelihood score is 6.16964223379403
# Number of Clusters = 21, The Silhouette Coefficient is 0.0010500456708296428
# Number of Clusters = 21, Homogeneity Score = 0.689920291972049
# Number of Clusters = 21, The log_likelihood score is 6.175544954983783
# Number of Clusters = 22, The Silhouette Coefficient is -0.002076311916218737
# Number of Clusters = 22, Homogeneity Score = 0.6967204836862514
# Number of Clusters = 22, The log_likelihood score is 6.188381298128034
# Number of Clusters = 23, The Silhouette Coefficient is 0.003377500861293391
# Number of Clusters = 23, Homogeneity Score = 0.6975181410509037
# Number of Clusters = 23, The log_likelihood score is 6.154037609316866
# Number of Clusters = 24, The Silhouette Coefficient is -0.001069019154764361
# Number of Clusters = 24, Homogeneity Score = 0.7050218469580428
# Number of Clusters = 24, The log_likelihood score is 6.2725465584106965
# Number of Clusters = 25, The Silhouette Coefficient is -0.008133802172046862
# Number of Clusters = 25, Homogeneity Score = 0.7051973885095632
# Number of Clusters = 25, The log_likelihood score is 6.303657822821426
# Number of Clusters = 26, The Silhouette Coefficient is -0.008418946074228141
# Number of Clusters = 26, Homogeneity Score = 0.6950658303063771
# Number of Clusters = 26, The log_likelihood score is 6.296002583859436
# Number of Clusters = 27, The Silhouette Coefficient is -0.003600058593498002
# Number of Clusters = 27, Homogeneity Score = 0.6794907929236479
# Number of Clusters = 27, The log_likelihood score is 6.298675462941325
# Number of Clusters = 28, The Silhouette Coefficient is -0.005156933136469754
# Number of Clusters = 28, Homogeneity Score = 0.6891396842498195
# Number of Clusters = 28, The log_likelihood score is 6.323658715025803
# Number of Clusters = 29, The Silhouette Coefficient is -0.0004810076864753368
# Number of Clusters = 29, Homogeneity Score = 0.6866437756924898
# Number of Clusters = 29, The log_likelihood score is 6.361889304442286
# Number of Clusters = 30, The Silhouette Coefficient is 0.0024964281917882565
# Number of Clusters = 30, Homogeneity Score = 0.6957551558976794
# Number of Clusters = 30, The log_likelihood score is 6.358123036202512
# 0.9082
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92      1577
#            2       0.90      0.90      0.90      2013
#            3       0.91      0.90      0.91      1410
#
#     accuracy                           0.91      5000
#    macro avg       0.91      0.91      0.91      5000
# weighted avg       0.91      0.91      0.91      5000
#
# [0.88817644 0.89205565 0.90224793 0.90595425 0.91192684 0.91399617
#  0.91810699 0.88608868 0.89406386 0.91429494] 0.902691174776091
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    8.6s finished
# [0.91084602 0.90863268 0.90848224] [0.90570115 0.90715229 0.90686659]
# EM
# SelectKBest Time:  192.69121823299997
#               precision    recall  f1-score   support
#
#            1    0.93224   0.87140   0.90079       521
#            2    0.85894   0.92620   0.89130       664
#            3    0.90828   0.87312   0.89035       465
#
#     accuracy                        0.89394      1650
#    macro avg    0.89982   0.89024   0.89415      1650
# weighted avg    0.89599   0.89394   0.89403      1650
#
# [[454  52  15]
#  [ 23 615  26]
#  [ 10  49 406]]
