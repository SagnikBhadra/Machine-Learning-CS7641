# %%
import mlrose_hiive
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
from randomized_algorithms import randomized_hill_climb, simulated_annealing, genetic_algorithm, mimic

# %%
if __name__ == "__main__":
    np.random.seed(42)
    knapsack_len=150
    weights = np.random.randint(1, 500, knapsack_len)
    values = np.random.randint(1, 500, knapsack_len)
    max_weight_pct = 0.5
    problem = mlrose_hiive.KnapsackOpt(weights=weights, values=values, max_weight_pct=max_weight_pct)

    
    randomized_hill_climb(problem)
    simulated_annealing(problem, temperature_list = [50, 100, 250, 500, 1000])
    genetic_algorithm(problem, population_sizes = [50, 100], mutation_rates = [0.1, 0.25, 0.5])
    mimic(problem, population_sizes = [500, 1000, 5000], keep_percent_list = [0.2, 0.25, 0.3])
# Out:
# Randimized Hill Climb
# Randimized Hill Climb Time:  48.391933407
# 92.0
# The average value of the fitness function was: 10460.821782178218
# The max value of the fitness function was: 21394.0
# The max run time of the algorithm was: 48.349377212
#
# Simulated Annealing
# Simulated Annealing Time:  1.1135032259999988
# The average value of the fitness function was: 21701.8
# The max value of the fitness function was: 23354.0
# The max run time of the algorithm was: 0.2446406620000019
# The average time for temperature 50 was: 0.06722742050000363
# The average time for temperature 100 was: 0.06367287499999819
# The average time for temperature 250 was: 0.09637665099999637
# The average time for temperature 500 was: 0.11558534599999959
# The average time for temperature 1000 was: 0.17956639400000185
# 1000
# Genetic Algorithm
# Genetic Algorithm Time:  7.417266724000001
# The average value of the fitness function was: 27544.833333333332
# The max value of the fitness function was: 28175.0
# The max run time of the algorithm was: 1.9964080640000006
# Mutation Rate
# 0.10    27671.0
# 0.25    27124.0
# 0.50    27839.5
# Name: Fitness, dtype: float64
# Population Size
# 50     27102.666667
# 100    27987.000000
# Name: Fitness, dtype: float64
# Population Size
# 50     0.847669
# 100    1.601829
# Name: Time, dtype: float64
#
# MIMIC
# MIMIC Time:  1201.782687232
# The average value of the fitness function was: 28203.11111111111
# The max value of the fitness function was: 28273.0
# The max run time of the algorithm was: 332.789368101
# Keep Percent
# 0.20    28227.000000
# 0.25    28187.000000
# 0.30    28195.333333
# Name: Fitness, dtype: float64
# Population Size
# 500     28109.666667
# 1000    28240.000000
# 5000    28259.666667
# Name: Fitness, dtype: float64
# Population Size
# 500      29.032143
# 1000     53.875517
# 5000    317.672877
# Name: Time, dtype: float64
