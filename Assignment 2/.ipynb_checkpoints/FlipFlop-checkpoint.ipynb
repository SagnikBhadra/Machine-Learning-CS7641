# %%
import mlrose_hiive
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
from randomized_algorithms import randomized_hill_climb, simulated_annealing, genetic_algorithm, mimic

# %%
"""
def randomized_hill_climb(problem):
    print('Randimized Hill Climb')
    start = timeit.default_timer()
    #%%time
    # DiscreteOpt() takes integers in range 0 to max_val-1

    runner_return = mlrose_hiive.RHCRunner(problem, experiment_name="first_try", 
                                           iteration_list=[10000],
                                           seed=42, max_attempts=100, 
                                           restart_list=[100])
    rhc_run_stats, rhc_run_curves = runner_return.run()
    
    stop = timeit.default_timer()
    print('Randimized Hill Climb Time: ', stop - start)  
    
    best_index_in_curve = rhc_run_curves.Fitness.idxmax()
    best_decay = rhc_run_curves.iloc[best_index_in_curve].current_restart
    best_curve = rhc_run_curves.loc[rhc_run_curves.current_restart == best_decay, :]
    best_curve.reset_index(inplace=True)
    print(best_decay)
    
    ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                             figsize=(12,8), grid=1,
                             title='Best Random Search')
    ax.set_xlabel("Iterations")
    ax.set_ylabel("Value")
    plt.show()

    last_iters = rhc_run_stats[rhc_run_stats.Iteration != 0].reset_index()
    print(last_iters.Fitness.mean(), last_iters.Fitness.max())
    print(last_iters.Time.max())
    
    
def simulated_annealing(problem):
    print('Simulated Annealing')
    start = timeit.default_timer()
    sa = mlrose_hiive.SARunner(problem, experiment_name="SA_Exp", 
                               iteration_list=[100000],
                               temperature_list=[1, 10, 50, 100, 250],
                               decay_list=[mlrose_hiive.ExpDecay,
                                           mlrose_hiive.GeomDecay],
                               seed=42, max_attempts=100)

    sa_run_stats, sa_run_curves = sa.run()
    
    stop = timeit.default_timer()
    print('Simulated Annealing Time: ', stop - start)  
    
    last_iters = sa_run_stats[sa_run_stats.Iteration != 0].reset_index()
    print(last_iters.Fitness.mean(), last_iters.Fitness.max())
    print(last_iters.Time.mean())
    
    print(last_iters.loc[last_iters.schedule_init_temp == 1, "Time"].mean())
    print(last_iters.loc[last_iters.schedule_init_temp == 10, "Time"].mean())
    print(last_iters.loc[last_iters.schedule_init_temp == 50, "Time"].mean())
    print(last_iters.loc[last_iters.schedule_init_temp == 100, "Time"].mean())
    print(last_iters.loc[last_iters.schedule_init_temp == 250, "Time"].mean())
    print(last_iters.loc[:, "Time"].mean())
    
    best_index_in_curve = sa_run_curves.Fitness.idxmax()
    best_decay = sa_run_curves.iloc[best_index_in_curve].Temperature
    best_curve = sa_run_curves.loc[sa_run_curves.Temperature == best_decay, :]
    best_curve.reset_index(inplace=True)
    print(best_decay)
    
    ax = best_curve.Fitness.plot(lw=2, colormap='jet', marker='.', markersize=2, 
                                 figsize=(12,8), grid=1,
                                 title='Best Simulated Annealing')
    ax.set_xlabel("Iterations")
    ax.set_ylabel("Value")
    plt.show()
    
    
def genetic_algorithm(problem):
    print('Genetic Algorithm')
    start = timeit.default_timer()
    ga = mlrose_hiive.GARunner(problem=problem,
                              experiment_name="GA_Exp",
                              seed=42,
                              iteration_list=[100000],
                              max_attempts=100,
                              population_sizes=[20,50,100],
                              mutation_rates=[0.1, 0.25, 0.5])
    ga_run_stats, ga_run_curves = ga.run()
    
    stop = timeit.default_timer()
    print('Genetic Algorithm Time: ', stop - start)  
    
    
    last_iters = ga_run_stats[ga_run_stats.Iteration != 0].reset_index()
    print("Max and mean")
    print(last_iters.Fitness.max(), last_iters.Fitness.mean(), last_iters.Time.mean())
    print(last_iters.groupby("Mutation Rate").Fitness.mean())
    print(last_iters.groupby("Population Size").Fitness.mean())
    print(last_iters.groupby("Population Size").Time.mean())
    
def mimic(problem):
    print('MIMIC')
    start = timeit.default_timer()
    mmc = mlrose_hiive.MIMICRunner(problem=problem,
                              experiment_name="MMC_Exp",
                              seed=42,
                              iteration_list=[100000],
                              max_attempts=100,
                              population_sizes=[20,50,100],
                              keep_percent_list=[0.25, 0.5, 0.75],
                              use_fast_mimic=True)

    # the two data frames will contain the results
    mmc_run_stats, mmc_run_curves = mmc.run()
    
    stop = timeit.default_timer()
    print('MIMIC Time: ', stop - start)  
    
    last_iters = mmc_run_stats[mmc_run_stats.Iteration != 0].reset_index()
    print("Max and mean")
    print(last_iters.Fitness.max(), last_iters.Fitness.mean(), last_iters.Time.mean())
    print(last_iters.groupby("Keep Percent").Fitness.mean())
    print(last_iters.groupby("Population Size").Fitness.mean())
    print(last_iters.groupby("Population Size").Time.mean())
"""
if __name__ == "__main__":
    np.random.seed(42)
    flip_len = 10
    problem = mlrose_hiive.FlipFlopOpt(length=flip_len)
    
    randomized_hill_climb(problem)
    simulated_annealing(problem)
    genetic_algorithm(problem)
    mimic(problem)
# Out:
# Randimized Hill Climb
# Randimized Hill Climb Time:  0.009492323999999996
# 0.0
# The average value of the fitness function was: 9.0
# The max value of the fitness function was: 9.0
# The max run time of the algorithm was: 0.004005739000000119
# Simulated Annealing
# Simulated Annealing Time:  0.4336160370000002
# The average value of the fitness function was: 9.0
# The max value of the fitness function was: 9.0
# The max run time of the algorithm was: 0.14685199100000013
# 1
# Genetic Algorithm
# Genetic Algorithm Time:  0.2446453479999997
# The average value of the fitness function was: 8.88888888888889
# The max value of the fitness function was: 9.0
# The max run time of the algorithm was: 0.09521764300000068
# Mutation Rate
# 0.10    9.000000
# 0.25    8.666667
# 0.50    9.000000
# Name: Fitness, dtype: float64
# Population Size
# 20     8.666667
# 50     9.000000
# 100    9.000000
# Name: Fitness, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-efc048570d41> in <module>
#     128     randomized_hill_climb(problem)
#     129     simulated_annealing(problem)
# --> 130     genetic_algorithm(problem)
#     131     mimic(problem)
#     132
#
# ~/Documents/GitHub/Machine-Learning-CS7641/Assignment 2/randomized_algorithms.py in genetic_algorithm(problem)
#      88     print(last_iters.groupby("Mutation Rate").Fitness.mean())
#      89     print(last_iters.groupby("Population Size").Fitness.mean())
# ---> 90     print(last_iters.groupby("Population Time").Time.mean())
#      91
#      92
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'Population Time'

# %%
# !pip install mlrose-hiive
# Out:
# Collecting mlrose-hiive
#   Downloading mlrose_hiive-2.2.4.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 844 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (1.20.1)
# Requirement already satisfied: scipy in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (1.6.2)
# Requirement already satisfied: scikit-learn in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (0.24.1)
# Requirement already satisfied: pandas in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (1.2.4)
# Requirement already satisfied: networkx in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (2.5)
# Requirement already satisfied: joblib in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from mlrose-hiive) (1.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from networkx->mlrose-hiive) (5.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas->mlrose-hiive) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from pandas->mlrose-hiive) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->mlrose-hiive) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sbhadra/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->mlrose-hiive) (2.1.0)
# Building wheels for collected packages: mlrose-hiive
#   Building wheel for mlrose-hiive (setup.py) ... done
#   Created wheel for mlrose-hiive: filename=mlrose_hiive-2.2.4-py3-none-any.whl size=98351 sha256=bc9bb04a1a25487b5892e38ea160a12c9cdd00806a5cea93ceec28e9a71dc15c
#   Stored in directory: /Users/sbhadra/Library/Caches/pip/wheels/3a/c5/8d/81f3616ac18fa05d4cbb01f9ec5b6e59cb8a83428d8e58505c
# Successfully built mlrose-hiive
# Installing collected packages: mlrose-hiive
# Successfully installed mlrose-hiive-2.2.4
