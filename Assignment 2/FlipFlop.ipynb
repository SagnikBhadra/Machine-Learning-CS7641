# %%
import mlrose_hiive
import numpy as np
import pandas as pd
import timeit
import matplotlib.pyplot as plt
from randomized_algorithms import randomized_hill_climb, simulated_annealing, genetic_algorithm, mimic

# %%
if __name__ == "__main__":
    np.random.seed(42)
    problem = mlrose_hiive.FlipFlopOpt(length=400)
    
    randomized_hill_climb(problem)
    simulated_annealing(problem, temperature_list = [25, 50, 100, 500])
    genetic_algorithm(problem, population_sizes = [20,50,100], mutation_rates = [0.1, 0.25, 0.5])
    mimic(problem, population_sizes = [20,50,100], keep_percent_list = [0.25, 0.5, 0.75])
# Out:
# Randimized Hill Climb
# Randimized Hill Climb Time:  1726.7232747649998
# 92.0
# The average value of the fitness function was: 312.019801980198
# The max value of the fitness function was: 330.0
# The max run time of the algorithm was: 1726.496858255
#
# Simulated Annealing
# Simulated Annealing Time:  2161.327602356
# The average value of the fitness function was: 388.0
# The max value of the fitness function was: 390.0
# The max run time of the algorithm was: 551.4703019139997
# The average time for temperature 25 was: 268.3691069654999
# The average time for temperature 50 was: 252.27823816449973
# The average time for temperature 100 was: 350.58450807949976
# The average time for temperature 500 was: 208.45353131799993
# 50
# Genetic Algorithm
# Genetic Algorithm Time:  20.93692244199974
# The average value of the fitness function was: 333.77777777777777
# The max value of the fitness function was: 347.0
# The max run time of the algorithm was: 3.1664742630000546
# Mutation Rate
# 0.10    324.333333
# 0.25    339.666667
# 0.50    337.333333
# Name: Fitness, dtype: float64
# Population Size
# 20     321.000000
# 50     337.333333
# 100    343.000000
# Name: Fitness, dtype: float64
# Population Size
# 20     1.431768
# 50     2.485474
# 100    3.032865
# Name: Time, dtype: float64
#
# MIMIC
# MIMIC Time:  280.00783108199994
# The average value of the fitness function was: 259.22222222222223
# The max value of the fitness function was: 303.0
# The max run time of the algorithm was: 59.59121033500014
# Keep Percent
# 0.25    253.666667
# 0.50    267.666667
# 0.75    256.333333
# Name: Fitness, dtype: float64
# Population Size
# 20     229.666667
# 50     260.333333
# 100    287.666667
# Name: Fitness, dtype: float64
# Population Size
# 20     13.080085
# 50     29.764741
# 100    50.472237
# Name: Time, dtype: float64
