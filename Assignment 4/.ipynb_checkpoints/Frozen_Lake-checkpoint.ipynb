# %%
import gym
import numpy as np
import random
from timeit import default_timer as timer
from datetime import timedelta
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
from gym.envs.toy_text.frozen_lake import generate_random_map, FrozenLakeEnv

from util import map_discretize, policy_numpy, see_policy, tsting

# %%
# !pip install gym
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 3.6 MB/s eta 0:00:01
# ...
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616829 sha256=6140f95049c9096a670c62af1c1056ffe9eedbc337bb5350c7bb34a4cc18d0a3
#   Stored in directory: /Users/sbhadra/Library/Caches/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
# Successfully built gym
# ...

# %%
def test_policy(env, policy, n_epoch=1000):
    rewards = []
    episode_counts = []
    for i in range(n_epoch):
        current_state = env.reset()
        ep = 0
        done = False
        episode_reward = 0
        while not done and ep < 1000:
            ep += 1
            act = int(policy[current_state])
            new_state, reward, done, _ = env.step(act)
            episode_reward += reward
            current_state = new_state
            
#         if ep>=1000:
#             print('over limit')
        rewards.append(episode_reward)
        episode_counts.append(ep)
    
    # all done
    mean_reward = sum(rewards)/len(rewards)
    mean_eps = sum(episode_counts)/len(episode_counts)
    return mean_reward, mean_eps, rewards, episode_counts

def value_iteration(env, discount=0.9, epsilon=1e-12):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    policy = np.zeros((1, number_of_states))
    value_list = np.zeros((1, number_of_states))
    old_value_list = value_list.copy()
    episode = 0
    max_change = 1
    sigma = discount
    while max_change > epsilon:
        episode += 1
        for s in range(number_of_states):
            assigned_value = -np.inf
            for a in range(number_of_actions):
                # get new state and its reward        
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    # get new states value
                    value_new_state = old_value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward 
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += cand_value*prob 
                        
                if total_cand_value > assigned_value:
                    assigned_value = total_cand_value
                    policy[0][s] = a
                    value_list[0][s] = assigned_value
        changes = np.abs(value_list - old_value_list)
        max_change = np.max(changes)
        old_value_list = value_list.copy()
        
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent


def policy_iteration(env, discount=0.9, epsilon=1e-3):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    ## 1
    policy = np.random.randint(number_of_actions, size=(1,number_of_states))
#     policy = np.zeros((1,number_of_states))
    value_list = np.zeros((1, number_of_states))
    episode = 0
    sigma = discount
    
    ## 2
    policy_stable = False
    while not policy_stable:
        episode += 1
        eval_acc = True
        while eval_acc:
            eps = 0
            for s in range(number_of_states):
                # first row
                v = value_list[0][s]

                # get the new value 
                a = policy[0][s]
                total_val_new_state = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    # second row
                    cand_value = 0
                    if done:
                        cand_value = reward                     
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_val_new_state += cand_value*prob 
                value_list[0][s] = total_val_new_state
                    
                # third row
                eps = max(eps, np.abs(v-value_list[0][s]))
            if eps < epsilon:
                eval_acc = False


        ## 3
        policy_stable = True
        for s in range(number_of_states):

            # assign 
            old_action = policy[0][s]
            # get the argmax a here
            max_value = -np.inf
            for a in range(number_of_actions):
                # get the new value 
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += prob*cand_value
                if total_cand_value > max_value:
                    max_value = total_cand_value
                    policy[0][s] = a

            # if old-action != policy[s]
            if old_action != policy[0][s]:
                policy_stable = False
    
    
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

def train_and_test_pi_vi(env, discount=[0.9], epsilon=[1e-9], mute=False):
    
    vi_dict = {}
    
    for dis in discount:
        vi_dict[dis] = {}
        for eps in epsilon:
            vi_dict[dis][eps] = {}
            
            # run value iteration
            vi_policy, vi_solve_iter, vi_solve_time = value_iteration(env, dis, eps)
            vi_mrews, vi_meps, _, __ = test_policy(env, vi_policy)    
            vi_dict[dis][eps]["mean_reward"] = vi_mrews
            vi_dict[dis][eps]["mean_eps"] = vi_meps
            vi_dict[dis][eps]["iteration"] = vi_solve_iter
            vi_dict[dis][eps]["time_spent"] = vi_solve_time
            vi_dict[dis][eps]["policy"] = vi_policy
            if not mute:
                print("Value iteration for {} discount and {} eps is done".format(dis, eps))
                print("Iteration: {} time: {}".format(vi_solve_iter, vi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(vi_mrews, vi_meps))
    # run policy iteration
    pi_dict = {}
    for dis in discount:
        pi_dict[dis] = {}
        for eps in epsilon:
            pi_dict[dis][eps] = {}

            pi_policy, pi_solve_iter, pi_solve_time = policy_iteration(env, dis, eps)
            pi_mrews, pi_meps, _, __ = test_policy(env, pi_policy)    
            pi_dict[dis][eps]["mean_reward"] = pi_mrews
            pi_dict[dis][eps]["mean_eps"] = pi_meps
            pi_dict[dis][eps]["iteration"] = pi_solve_iter
            pi_dict[dis][eps]["time_spent"] = pi_solve_time
            pi_dict[dis][eps]["policy"] = pi_policy
            if not mute:
                print("Policy iteration for {} discount is done".format(dis))
                print("Iteration: {} time: {}".format(pi_solve_iter, pi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(pi_mrews, pi_meps))

    
    return vi_dict, pi_dict

def map_discretize(the_map):
    size = len(the_map)
    dis_map = np.zeros((size,size))
    for i, row in enumerate(the_map):
        for j, loc in enumerate(row):
            if loc == "S":
                dis_map[i, j] = 0
            elif loc == "F":
                dis_map[i, j] = 0
            elif loc == "H":
                dis_map[i, j] = -1
            elif loc == "G":
                dis_map[i, j] = 1
    return dis_map


def policy_numpy(policy):
    size = int(np.sqrt(len(policy)))
    pol = np.asarray(policy)
    pol = pol.reshape((size, size))
    return pol


def see_policy(map_size, policy):
    map_name = str(map_size)+"x"+str(map_size)
    data = map_discretize(MAPS[map_name])
    np_pol = policy_numpy(policy)
    plt.imshow(data, interpolation="nearest")

    for i in range(np_pol[0].size):
        for j in range(np_pol[0].size):
            arrow = '\u2190'
            if np_pol[i, j] == 1:
                arrow = '\u2193'
            elif np_pol[i, j] == 2:
                arrow = '\u2192'
            elif np_pol[i, j] == 3:
                arrow = '\u2191'
            text = plt.text(j, i, arrow,
                           ha="center", va="center", color="w")
    plt.show()

    
def plot_the_dict(dictionary, value="Score", size=4, variable="Discount Rate", log=False):

    plt.figure(figsize=(12, 8))
    title = "Average and Max {} on {}x{} Frozen Lake".format(value, size, size)
    the_val = value
    value = "Average {}".format(the_val)
    val_type = "Type of {}".format(the_val)
    the_df = pd.DataFrame(columns=[variable, value, val_type])
    for k, v in dictionary.items():
        for val in v:
            if not log:
                dic = {variable: k, value: float(val), val_type: "Average with std"}
            else:
                dic = {variable: np.log10(k), value: float(val), val_type: "Average with std"}                
            the_df = the_df.append(dic, ignore_index=True)
        if not log:
            dic = {variable: k, value: float(max(v)), val_type: "Max"}
        else:
            dic = {variable: np.log10(k), value: float(max(v)), val_type: "Max"}
        the_df = the_df.append(dic, ignore_index=True)
    sns.lineplot(x=variable, y=value, hue=val_type, style=val_type, markers=True, data=the_df).set(title=title)

    
def convert_dict_to_dict(the_dict):
    
    # return for discount
    discount_rewards = {}
    discount_iterations = {}
    discount_times = {}


    for disc in the_dict:
        discount_rewards[disc] = []    
        discount_iterations[disc] = []    
        discount_times[disc] = []

        for eps in the_dict[disc]:
            discount_rewards[disc].append(the_dict[disc][eps]['mean_reward'])
            discount_iterations[disc].append(the_dict[disc][eps]['iteration'])        
            discount_times[disc].append(the_dict[disc][eps]['time_spent'].total_seconds())  

            
    epsilon_rewards = {}
    epsilon_iterations = {}
    epsilon_times = {}
    for eps in the_dict[0.5]:
        epsilon_rewards[eps] = []    
        epsilon_iterations[eps] = []    
        epsilon_times[eps] = []
    
        for disc in vi_dict:
            epsilon_rewards[eps].append(the_dict[disc][eps]['mean_reward'])
            epsilon_iterations[eps].append(the_dict[disc][eps]['iteration'])        
            epsilon_times[eps].append(the_dict[disc][eps]['time_spent'].total_seconds()) 
            
    return discount_rewards, discount_iterations, discount_times, epsilon_rewards, epsilon_iterations, epsilon_times


if __name__ == "__main__":
    np.random.seed(2)
    sixteen = generate_random_map(16)
    np.random.seed(44)
    tvelve = generate_random_map(12)
    MAPS = {
        "4x4": [
            "SFFF",
            "FHFH",
            "FFFH",
            "HFFG"
        ],
        "8x8": [
            "SFFFFFFF",
            "FFFFFFFF",
            "FFFHFFFF",
            "FFFFFHFF",
            "FFFHFFFF",
            "FHHFFFHF",
            "FHFFHFHF",
            "FFFHFFFG"
        ],
        "12x12": tvelve,
        "16x16": sixteen
    }
    
    print("4x4")
    
    env = gym.make("FrozenLake-v1")
    vi_dict, pi_dict = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                        epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
    
    print(f'Value Iteration: \n {vi_dict[0.99]}')
    print(f'Policy Iteration: \n {pi_dict[0.9999]}')
    
    pol = vi_dict[0.99][1e-12]['policy']
    vi4 = convert_dict_to_dict(vi_dict)
    see_policy(4, pol)
    
    plot_the_dict(vi4[0], value="Score", size=4)
    
    
    plot_the_dict(vi4[1], value="Iteration", size=4)
    
    plot_the_dict(vi4[2], value="Time", size=4)
    
    plot_the_dict(vi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)
    
    plot_the_dict(vi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)
    
    plot_the_dict(vi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)
    
    
    pol = pi_dict[0.99][1e-12]['policy']
    pi4 = convert_dict_to_dict(pi_dict)
    see_policy(4, pol)
    
    plot_the_dict(pi4[0], value="Score", size=4)
    
    plot_the_dict(pi4[1], value="Iteration", size=4)
    
    plot_the_dict(pi4[2], value="Time", size=4)
    
    plot_the_dict(pi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)
    
    plot_the_dict(pi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)
    
    plot_the_dict(pi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)
    
    
    
    print("16x16")
    
    env = FrozenLakeEnv(desc=MAPS["16x16"])
    vi_dict16, pi_dict16 = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                              epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
    
    
    pol = vi_dict16[0.9999][1e-15]['policy']
    vi16 = convert_dict_to_dict(vi_dict16)
    see_policy(16, pol)
    
    plot_the_dict(vi16[0], value="Score", size=16)
    
    plot_the_dict(vi16[1], value="Iteration", size=16)
    
    plot_the_dict(vi16[2], value="Time", size=16)

    pi16 = convert_dict_to_dict(pi_dict16)
    plot_the_dict(pi16[0], value="Score", size=16)
    
    plot_the_dict(pi16[1], value="Iteration", size=16)
    
    
    plot_the_dict(pi16[2], value="Time", size=16)
# Out:
# 4x4
# Solved in: 7 episodes and 0:00:00.001310 seconds
# Solved in: 16 episodes and 0:00:00.002099 seconds
# Solved in: 25 episodes and 0:00:00.003091 seconds
# Solved in: 34 episodes and 0:00:00.004528 seconds
# Solved in: 44 episodes and 0:00:00.006724 seconds
# Solved in: 12 episodes and 0:00:00.001511 seconds
# Solved in: 33 episodes and 0:00:00.004196 seconds
# Solved in: 53 episodes and 0:00:00.007024 seconds
# Solved in: 73 episodes and 0:00:00.010392 seconds
# Solved in: 94 episodes and 0:00:00.011645 seconds
# Solved in: 27 episodes and 0:00:00.003348 seconds
# Solved in: 78 episodes and 0:00:00.009433 seconds
# Solved in: 129 episodes and 0:00:00.017935 seconds
# Solved in: 179 episodes and 0:00:00.023970 seconds
# Solved in: 230 episodes and 0:00:00.029870 seconds
# Solved in: 44 episodes and 0:00:00.005703 seconds
# Solved in: 128 episodes and 0:00:00.016396 seconds
# Solved in: 213 episodes and 0:00:00.032537 seconds
# Solved in: 297 episodes and 0:00:00.038895 seconds
# ...

# %%
def tsting(game, algo_array, iterations=1000):
    scores = []
    array_of_iterations = []
    for i in range(iterations):
        x = game.reset()
        iter = 0
        complete = False
        iteration_score = 0
        while not complete and iter < 1000:
            iter += 1
            action = int(algo_array[x])
            s_prime, score, complete, tmp = game.step(action)
            iteration_score += score
            x = s_prime
            
        scores.append(iteration_score)
        array_of_iterations.append(iter)
    
    # all complete
    average_score = sum(scores)/len(scores)
    average_episodes = sum(array_of_iterations)/len(array_of_iterations)
    return average_score, average_episodes, scores, array_of_iterations

def vi_func(game, gamma=0.9, epsilon=1e-12):
    
    begin = timer()
    
    space_len = game.observation_space.n
    action_len = game.action_space.n
    algo_array = np.zeros((1, space_len))
    v_matrix = np.zeros((1, space_len))
    v_prior_matrix = v_matrix.copy()
    iteration = 0
    highest_delta = 1
    while highest_delta > epsilon:
        iteration += 1
        for x in range(space_len):
            v_star = -np.inf
            for y in range(action_len):
                # get new state and its score        
                sum_of_v = 0
                for chance, s_prime, score, complete in game.P[x][y]:
                    # get new states value
                    v_prime_matrix = v_prior_matrix[0][s_prime]
                    current_score = 0
                    if complete:
                        current_score = score 
                    else:
                        current_score = score + gamma * v_prime_matrix
                    sum_of_v += current_score * chance 
                        
                if sum_of_v > v_star:
                    v_star = sum_of_v
                    algo_array[0][x] = y
                    v_matrix[0][x] = v_star
        
        highest_delta = np.max(np.abs(v_matrix - v_prior_matrix))
        v_prior_matrix = v_matrix.copy()
        
    finish = timer()
    seconds_takens = timedelta(seconds=finish-begin)
    print("Solved in: {} episodes and {} seconds".format(iteration, seconds_takens))
    return algo_array[0], iteration, seconds_takens


def pi_func(game, gamma=0.9, epsilon=1e-3):
    
    begin = timer()
    
    space_len = game.observation_space.n
    action_len = game.action_space.n
    ## 1
    algo_array = np.random.randint(action_len, size=(1,space_len))

    v_matrix = np.zeros((1, space_len))
    iteration = 0
    
    ## 2
    covergence = False
    while not covergence:
        iteration += 1
        complete = True
        while complete:
            num_of_episode = 0
            for x in range(space_len):
                # first row
                value = v_matrix[0][x]

                
                y = algo_array[0][x]
                sum_value_prime = 0
                for chance, s_prime, score, complete in game.P[x][y]:
                    v_prime_matrix = v_matrix[0][s_prime]
                    
                    current_score = 0
                    if complete:
                        current_score = score                     
                    else:
                        current_score = score + gamma*v_prime_matrix
                    sum_value_prime += current_score * chance 
                v_matrix[0][x] = sum_value_prime
                    
                # third row
                num_of_episode = max(num_of_episode, np.abs(value-v_matrix[0][x]))
            if num_of_episode < epsilon:
                complete = False


        ## 3
        covergence = True
        for x in range(space_len):

            # assign 
            prior_y = algo_array[0][x]
            # get the argmax y here
            highest_v = -np.inf
            for y in range(action_len):
                # get the new value 
                sum_of_v = 0
                for chance, s_prime, score, complete in game.P[x][y]:
                    v_prime_matrix = v_matrix[0][s_prime]
                    current_score = 0
                    if complete:
                        current_score = score
                    else:
                        current_score = score + gamma*v_prime_matrix
                    sum_of_v += chance * current_score
                if sum_of_v > highest_v:
                    highest_v = sum_of_v
                    algo_array[0][x] = y

            if prior_y != algo_array[0][x]:
                covergence = False
    
    
    finish = timer()
    seconds_takens = timedelta(seconds=finish-begin)
    print("Solved in: {} episodes and {} seconds".format(iteration, seconds_takens))
    return algo_array[0], iteration, seconds_takens

def run_value_policy_iter(game, gamma=[0.9], epsilon=[1e-9], verbose=True):
    
    value_iteration_matrix = {}
    
    for gamma_instance in gamma:
        value_iteration_matrix[gamma_instance] = {}
        for num_of_episode in epsilon:
            value_iteration_matrix[gamma_instance][num_of_episode] = {}
            
            # run value iteration
            algorithm_decision, total_num_of_iterations, total_num_of_seconds_taken = vi_func(game, gamma_instance, num_of_episode)
            value_iteration_average_score, value_iteration_average_episodes, tmp1, tmp2 = tsting(game, algorithm_decision)    
            value_iteration_matrix[gamma_instance][num_of_episode]["average_score"] = value_iteration_average_score
            value_iteration_matrix[gamma_instance][num_of_episode]["average_episodes"] = value_iteration_average_episodes
            value_iteration_matrix[gamma_instance][num_of_episode]["iteration"] = total_num_of_iterations
            value_iteration_matrix[gamma_instance][num_of_episode]["seconds_takens"] = total_num_of_seconds_taken
            value_iteration_matrix[gamma_instance][num_of_episode]["policy"] = algorithm_decision
            if verbose:
                print("Value iteration for {} gamma and {} num_of_episode is complete".format(gamma_instance, num_of_episode))
                print("Iteration: {} time: {}".format(total_num_of_iterations, total_num_of_seconds_taken))
                print("Mean score: {} - mean num_of_episode: {}".format(value_iteration_average_score, value_iteration_average_episodes))
    # run policy iteration
    policy_iteration_matrix = {}
    for gamma_instance in gamma:
        policy_iteration_matrix[gamma_instance] = {}
        for num_of_episode in epsilon:
            policy_iteration_matrix[gamma_instance][num_of_episode] = {}

            algorithm_decision, total_num_of_iterations, policy_total_num_of_seconds_taken = pi_func(game, gamma_instance, num_of_episode)
            policy_iteration_average_score, policy_iteration_average_episodes, tmp, tmp2 = tsting(game, algorithm_decision)    
            policy_iteration_matrix[gamma_instance][num_of_episode]["average_score"] = policy_iteration_average_score
            policy_iteration_matrix[gamma_instance][num_of_episode]["average_episodes"] = policy_iteration_average_episodes
            policy_iteration_matrix[gamma_instance][num_of_episode]["iteration"] = total_num_of_iterations
            policy_iteration_matrix[gamma_instance][num_of_episode]["seconds_takens"] = policy_total_num_of_seconds_taken
            policy_iteration_matrix[gamma_instance][num_of_episode]["policy"] = algorithm_decision
            if verbose:
                print("Policy iteration for {} gamma is complete".format(gamma_instance))
                print("Iteration: {} time: {}".format(total_num_of_iterations, policy_total_num_of_seconds_taken))
                print("Mean score: {} - mean num_of_episode: {}".format(policy_iteration_average_score, policy_iteration_average_episodes))

    
    return value_iteration_matrix, policy_iteration_matrix

    
def draw_figure(dictionary, score="Score", size=4, variable="Discount Rate", verbose=False):

    plt.figure(figsize=(12, 8))
    title = "Average and Max {} on {}x{} Frozen Lake".format(score, size, size)
    val_type = "Type of {}".format(score)
    score = "Average {}".format(score)
    figure_data = pd.DataFrame(columns=[variable, score, val_type])
    plt.title(title)
    for index, value in dictionary.items():
        for i in value:
            if not verbose:
                matrix = {variable: index, score: float(i), val_type: "Average with std"}
            else:
                matrix = {variable: np.log10(index), score: float(i), val_type: "Average with std"}                
            figure_data = figure_data.append(matrix, ignore_index=True)
        if not verbose:
            matrix = {variable: index, score: float(max(value)), val_type: "Max"}
        else:
            matrix = {variable: np.log10(index), score: float(max(value)), val_type: "Max"}
        figure_data = figure_data.append(matrix, ignore_index=True)
    sns.lineplot(x=variable, y=score, hue=val_type, style=val_type, markers=True, data=figure_data).set(title=title)
    plt.savefig(title)
    plt.show()

    
def data_structure(matrix):
    
    # return for gamma
    gamma_scores = {}
    gamma_episodes = {}
    gamma_length = {}


    for gam in matrix:
        gamma_scores[gam] = []    
        gamma_episodes[gam] = []    
        gamma_length[gam] = []

        for num_of_episode in matrix[gam]:
            gamma_scores[gam].append(matrix[gam][num_of_episode]['average_score'])
            gamma_episodes[gam].append(matrix[gam][num_of_episode]['iteration'])        
            gamma_length[gam].append(matrix[gam][num_of_episode]['seconds_takens'].total_seconds())  

            
    lowest_change_scores = {}
    lowest_change_episodes = {}
    lowest_change_length = {}
    for num_of_episode in matrix[0.99]:
        lowest_change_scores[num_of_episode] = []    
        lowest_change_episodes[num_of_episode] = []    
        lowest_change_length[num_of_episode] = []
    
        for gam in value_iteration_matrix:
            lowest_change_scores[num_of_episode].append(matrix[gam][num_of_episode]['average_score'])
            lowest_change_episodes[num_of_episode].append(matrix[gam][num_of_episode]['iteration'])        
            lowest_change_length[num_of_episode].append(matrix[gam][num_of_episode]['seconds_takens'].total_seconds()) 
            
    return gamma_scores, gamma_episodes, gamma_length, lowest_change_scores, lowest_change_episodes, lowest_change_length


if __name__ == "__main__":
    np.random.seed(2)
    sixteen = generate_random_map(16)
    np.random.seed(44)
    tvelve = generate_random_map(12)
    MAPS = {
        "4x4": [
            "SFFF",
            "FHFH",
            "FFFH",
            "HFFG"
        ],
        "8x8": [
            "SFFFFFFF",
            "FFFFFFFF",
            "FFFHFFFF",
            "FFFFFHFF",
            "FFFHFFFF",
            "FHHFFFHF",
            "FHFFHFHF",
            "FFFHFFFG"
        ],
        "12x12": tvelve,
        "16x16": sixteen
    }
    
    print("4x4")
    
    game = gym.make("FrozenLake-v1")
    value_iteration_matrix, policy_iteration_matrix = run_value_policy_iter(game, gamma=[0.7, 0.8, 0.9, 0.95, 0.99, 0.9999], 
                                        epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], verbose=True)
    
    print(f'Value Iteration: \n {value_iteration_matrix[0.99]}')
    print(f'Policy Iteration: \n {policy_iteration_matrix[0.9999]}')
    
    decisions = value_iteration_matrix[0.99][1e-12]['policy']
    value_iteration_results = data_structure(value_iteration_matrix)
    see_policy(4, decisions, MAPS)
    
    draw_figure(value_iteration_results[0], score="Score", size=4)
    
    
    draw_figure(value_iteration_results[1], score="Iteration", size=4)
    
    draw_figure(value_iteration_results[2], score="Time", size=4)
    
    draw_figure(value_iteration_results[3], score="Score", size=4, variable="Log Epsilon Value", verbose=True)
    
    draw_figure(value_iteration_results[4], score="Iteration", size=4, variable="Log Epsilon Value", verbose=True)
    
    draw_figure(value_iteration_results[5], score="Time", size=4, variable="Log Epsilon Value", verbose=True)
    
    
    decisions = policy_iteration_matrix[0.99][1e-12]['policy']
    policy_iteration_results = data_structure(policy_iteration_matrix)
    see_policy(4, decisions, MAPS)
    
    draw_figure(policy_iteration_results[0], score="Score", size=4)
    
    draw_figure(policy_iteration_results[1], score="Iteration", size=4)
    
    draw_figure(policy_iteration_results[2], score="Time", size=4)
    
    draw_figure(policy_iteration_results[3], score="Score", size=4, variable="Log Epsilon Value", verbose=True)
    
    draw_figure(policy_iteration_results[4], score="Iteration", size=4, variable="Log Epsilon Value", verbose=True)
    
    draw_figure(policy_iteration_results[5], score="Time", size=4, variable="Log Epsilon Value", verbose=True)
    
    
    
    print("16x16")
    
    game = FrozenLakeEnv(desc=MAPS["16x16"])
    value_iteration_matrix, policy_iteration_matrix = run_value_policy_iter(game, gamma=[0.7, 0.8, 0.9, 0.95, 0.99, 0.9999], epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], verbose=True)
    
    
    decisions = value_iteration_matrix[0.9999][1e-15]['policy']
    value_iteration_results = data_structure(value_iteration_matrix)
    see_policy(16, decisions, MAPS)
    
    draw_figure(value_iteration_results[0], score="Score", size=16)
    
    draw_figure(value_iteration_results[1], score="Iteration", size=16)
    
    draw_figure(value_iteration_results[2], score="Time", size=16)

    policy_iteration_results = data_structure(policy_iteration_matrix)
    draw_figure(policy_iteration_results[0], score="Score", size=16)
    
    draw_figure(policy_iteration_results[1], score="Iteration", size=16)
    
    
    draw_figure(policy_iteration_results[2], score="Time", size=16)
# Out:
# 4x4
# Solved in: 11 episodes and 0:00:00.001738 seconds
# Value iteration for 0.7 gamma and 0.001 num_of_episode is complete
# Iteration: 11 time: 0:00:00.001738
# Mean score: 0.432 - mean num_of_episode: 28.492
# Solved in: 27 episodes and 0:00:00.003618 seconds
# Value iteration for 0.7 gamma and 1e-06 num_of_episode is complete
# Iteration: 27 time: 0:00:00.003618
# Mean score: 0.435 - mean num_of_episode: 27.557
# Solved in: 44 episodes and 0:00:00.005758 seconds
# Value iteration for 0.7 gamma and 1e-09 num_of_episode is complete
# Iteration: 44 time: 0:00:00.005758
# Mean score: 0.432 - mean num_of_episode: 27.07
# Solved in: 61 episodes and 0:00:00.009644 seconds
# Value iteration for 0.7 gamma and 1e-12 num_of_episode is complete
# Iteration: 61 time: 0:00:00.009644
# Mean score: 0.432 - mean num_of_episode: 26.979
# Solved in: 78 episodes and 0:00:00.010911 seconds
# Value iteration for 0.7 gamma and 1e-15 num_of_episode is complete
# Iteration: 78 time: 0:00:00.010911
# ...
