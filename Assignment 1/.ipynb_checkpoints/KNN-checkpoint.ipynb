# %%
import numpy as np
import sklearn
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('figure', figsize=[10,5])
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, accuracy_score, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone
from sklearn.model_selection import validation_curve
from sklearn.metrics import roc_curve, precision_score, accuracy_score, average_precision_score, recall_score, f1_score, classification_report, confusion_matrix
from util import stratFold, plot_learning_curve, plot_complexity, plot_roc_curve, normalize_data, create_stratified_data, prepare_data

# %%
# stratified cross validation

def stratFold(train_X_all, train_y_all, classifier, metric, average=None,
              fold=5, min_start=100):
    train_metric, val_metric, indices = [], [], []
    for m in range(min_start, len(train_X_all), 100):
        train_X = train_X_all[:m]
        train_y = train_y_all[:m]
        skfolds = StratifiedKFold(n_splits=fold)
        metric_list = []
        metric_list_train = []
        for train_index, test_index in skfolds.split(train_X, train_y):
            train_X_folds = train_X.iloc[train_index]
            train_y_folds = train_y.iloc[train_index]
            test_X_fold = train_X.iloc[test_index]
            test_y_fold = train_y.iloc[test_index]
            classifier.fit(train_X_folds.values, train_y_folds.values.ravel())
            train_y_folds_pred = classifier.predict(train_X_folds)
            test_y_fold_pred = classifier.predict(test_X_fold)
            if average:
                metric_list.append(metric(test_y_fold.values, test_y_fold_pred,
                                     average=average))
                metric_list_train.append(metric(train_y_folds.values, train_y_folds_pred, 
                                            average=average))
            else:
                metric_list.append(metric(test_y_fold.values, test_y_fold_pred))
                metric_list_train.append(metric(train_y_folds.values, train_y_folds_pred))
                
        test_avg = sum(metric_list)/len(metric_list)
        train_avg = sum(metric_list_train)/len(metric_list_train)
        val_metric.append(test_avg)
        train_metric.append(train_avg)
        indices.append(m)
    
    return train_metric, val_metric, indices


def plot_learning_curve(train_scores, val_scores, indices, title, inverse_x=False):
    plt.plot(indices, train_scores , "r-+", linewidth=2, label="train")
    plt.plot(indices, val_scores, "b-+", linewidth=2, label="validation")
    plt.title(title)
    plt.legend()
    plt.xlabel('Number of Training Instances Used')
    
    plt.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.3)
    if inverse_x:
        plt.gca().invert_xaxis()
    plt.show()
        
        
def plot_complexity(train_scores, val_scores, indices, title, inverse_x=True):
    plt.plot(indices, train_scores , "r-+", linewidth=2, label="train")
    plt.plot(indices, val_scores, "b-+", linewidth=2, label="validation")
    plt.title(title)
    plt.legend()
    plt.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.3)
    if inverse_x:
        plt.gca().invert_xaxis()
    plt.show()

        
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0,1], [0,1], 'k--')
    plt.axis([0,1,0,1])
    plt.legend()
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.show()
    
def normalize_data(dataset):
    # normalize features for better performance 
    x = dataset.values # convert to numpy array
    #print(x.shape)
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    #print(x_scaled.shape)
    dataset = pd.DataFrame(x_scaled, columns=dataset.columns)
    #wine_dataset.head()
    return dataset

def create_stratified_data(target_feature, dataset):
    # stratified sampling

    split = StratifiedShuffleSplit(n_splits=1 , test_size=0.2, random_state=30)
    for train_ind, test_ind in split.split(dataset, dataset[target_feature]):
        strat_train_set = dataset.loc[train_ind]
        strat_test_set = dataset.loc[test_ind]
        
    return strat_train_set, strat_test_set

def prepare_data(train_set, test_set, target_feature):
    train_y = train_set[[target_feature]]
    train_X = train_set.drop(target_feature, axis=1)
    test_y = test_set[[target_feature]]
    test_X = test_set.drop(target_feature, axis=1)
    
    return train_y, train_X, test_y, test_X

def define_KNN(train_X, train_y):
    neigh = KNeighborsClassifier()
    neigh.fit(train_X, train_y.values.ravel())
    
    print(neigh)
    return neigh

def KNN_predictions(neigh, train_X, train_y):
    # first net results
    train_predictions = neigh.predict(train_X)
    accuracy = accuracy_score(train_y, train_predictions)
    print(accuracy)
    print(classification_report(train_y, train_predictions))
    return accuracy


def compute_score(train_X, train_y, neigh, average):
    f1_scores = stratFold(train_X, train_y, neigh, f1_score, average=average)
    plot_learning_curve(f1_scores[0], f1_scores[1], f1_scores[2], title="f1_macro score learning curve")
    

def run_gridsearch(param_grid, train_X, train_y, cv, scoring, n_jobs):
    search_f1 = GridSearchCV(MLPClassifier(), param_grid, cv=cv, scoring=scoring, n_jobs = n_jobs)
    search_f1.fit(train_X, train_y.values.ravel())
    print(search_f1.best_estimator_, search_f1.best_score_)
    
    return search_f1
    
    
def run_validation_curve(neigh, train_X, train_y, param_range, scoring, param_name, inverse_x, cv, title):
    train_scores, test_scores = validation_curve(
        neigh, train_X, train_y.values.ravel(), param_name=param_name, param_range=param_range,
        scoring=scoring, verbose=1, cv=cv, n_jobs=-1
    )
    print(train_scores.mean(axis=1), test_scores.mean(axis=1), param_range)
    plot_complexity(train_scores.mean(axis=1), test_scores.mean(axis=1), param_range, 
                    title='f1_weighted score', inverse_x=inverse_x)
    
    return train_scores, test_scores

def wine_dataset():
    target_feature = "class"
    alpha = 0.005
    criterion = "entropy"
    average = "weighted"
    scoring = "f1_weighted"
    param_name = "n_neighbors"
    cv = 10
    n_jobs = -1
    inverse_x = True
    
    
    np.random.seed(44)
    wine_dataset = pd.read_csv("wine_dataset.csv")
    print(wine_dataset.info())
    wine_dataset.head()
    
    target = wine_dataset[target_feature]
    wine_dataset = normalize_data(wine_dataset)
    wine_dataset[target_feature] = target
    
    strat_train_set, strat_test_set = create_stratified_data(target_feature, wine_dataset)
    
    train_set = strat_train_set
    test_set = strat_test_set
    
    train_y, train_X, test_y, test_X = prepare_data(train_set, test_set, target_feature)
    
    neigh = define_KNN(train_X, train_y)
    
    accuracy = KNN_predictions(neigh, train_X, train_y)
    
    scores = cross_val_score(neigh, train_X, train_y.values.ravel(), scoring=scoring, cv=cv)
    scores.mean()
    
    compute_score(train_X, train_y, neigh, average)
    
    neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                                 weights='distance')
    
    param_range = [1,2,5,10,20,30,50,75,100,150,200]
    title='f1_weighted score'
    train_scores, test_scores = run_validation_curve(neigh, train_X, train_y, param_range, scoring, param_name, inverse_x, cv, title)
    
    
    neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                                 weights='distance')

    param_range = [1,2,5,10,20,30,50,75,100,150,200]
    train_scores, test_scores = run_validation_curve(neigh, train_X, train_y, param_range, scoring, param_name, inverse_x, cv, title)
    
    
    best_neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=30, p=2,
                                 weights='uniform')

    compute_score(train_X, train_y, best_neigh, average)



    # test with the test data
    best_neigh.fit(train_X, train_y.values.ravel())
    test_predictions = best_neigh.predict(test_X)
    print(classification_report(test_y, test_predictions,digits=5))
    print(confusion_matrix(test_y, test_predictions))
    
    
    
if __name__ == "__main__":
    wine_dataset()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   class                    5000 non-null   int64
#  1   Alcohol                  5000 non-null   float64
#  2   Malic_acid               5000 non-null   float64
#  3   Ash                      5000 non-null   float64
#  4   Alcalinity_of_ash        5000 non-null   float64
#  5   Magnesium                5000 non-null   float64
#  6   Total_phenols            5000 non-null   float64
#  7   Flavanoids               5000 non-null   float64
#  8   Nonflavanoid_phenols     5000 non-null   float64
#  9   Proanthocyanins          5000 non-null   float64
#  10  Color_intensity          5000 non-null   float64
#  11  Hue                      5000 non-null   float64
#  12  Od_Hod_of_diluted_wines  5000 non-null   float64
# ...

# %%
def ufc_dataset():
    target_feature = "Winner"
    alpha = 0.005
    criterion = "entropy"
    average = "macro"
    scoring = "f1_macro"
    param_name = "n_neighbors"
    cv = 10
    n_jobs = -1
    inverse_x = True
    
    
    np.random.seed(44)
    ufc_dataset = pd.read_csv("ufc_data.csv")
    print(ufc_dataset.info())
    ufc_dataset.head()
    
    # red is 1, blue is 0
    # drop the no_of_rounds because unknown in the beginning
    ufc_dataset.loc[ufc_dataset["Winner"] == "Red", "Winner"] = 1
    ufc_dataset.loc[ufc_dataset["Winner"] == "Blue", "Winner"] = 0
    ufc_dataset.drop(["no_of_rounds"], axis=1 ,inplace=True)
    # al zero
    ufc_dataset.drop(["B_draw"], axis=1 ,inplace=True)
    ufc_dataset.drop(["R_draw"], axis=1 ,inplace=True)
    
    ufc_dataset = normalize_data(ufc_dataset)
    
    strat_train_set, strat_test_set = create_stratified_data(target_feature, ufc_dataset)
    
    train_set = strat_train_set
    test_set = strat_test_set
    
    train_y, train_X, test_y, test_X = prepare_data(train_set, test_set, target_feature)
    
    neigh = define_KNN(train_X, train_y)
    
    accuracy = KNN_predictions(neigh, train_X, train_y)
    
    scores = cross_val_score(neigh, train_X, train_y.values.ravel(), scoring=scoring, cv=cv)
    scores.mean()
    
    compute_score(train_X, train_y, neigh, average)
    
    neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                             weights='uniform')

    param_range = [2,5,10,20,30,50,75,100,150,200]
    title='f1_macro score'
    train_scores, test_scores = run_validation_curve(neigh, train_X, train_y, param_range, scoring, param_name, inverse_x, cv, title)
    
    
    neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                             weights='distance')

    param_range = [12,5,10,20,30,50,75,100,150,200]
    train_scores, test_scores = run_validation_curve(neigh, train_X, train_y, param_range, scoring, param_name, inverse_x, cv, title)
    
    
    
    best_neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=2, p=2,
                             weights='distance')

    compute_score(train_X, train_y, best_neigh, average)



    # test with the test data
    best_neigh.fit(train_X, train_y.values.ravel())
    test_predictions = best_neigh.predict(test_X)
    print(classification_report(test_y, test_predictions,digits=5))
    print(confusion_matrix(test_y, test_predictions))
    
ufc_dataset()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3592 entries, 0 to 3591
# Columns: 160 entries, Winner to R_Stance_Switch
# dtypes: bool(1), float64(134), int64(24), object(1)
# memory usage: 4.4+ MB
# None
# KNeighborsClassifier()
# 0.757396449704142
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.51      0.59       969
#          1.0       0.78      0.88      0.83      1904
#
#     accuracy                           0.76      2873
#    macro avg       0.74      0.70      0.71      2873
# weighted avg       0.75      0.76      0.75      2873
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    5.8s finished
# [0.79853387 0.7031372  0.65714532 0.57944057 0.52031498 0.47131801
#  0.43587895 0.42697842 0.41347284 0.40847055] [0.52924491 0.53853956 0.54259834 0.51236514 0.4727108  0.45136128
# ...

# %%
def define_KNN(input_train_set, output_train_set):
    KNN_Learner = KNeighborsClassifier()
    KNN_Learner.fit(input_train_set, output_train_set.values.ravel())
    
    print(KNN_Learner)
    return KNN_Learner

def KNN_predictions(KNN_Learner, input_train_set, output_train_set):
    # first net results
    y_hat = KNN_Learner.predict(input_train_set)
    percent_match = accuracy_score(output_train_set, y_hat)
    print(percent_match)
    print(classification_report(output_train_set, y_hat))
    return percent_match


def compute_score(input_train_set, output_train_set, KNN_Learner, mean):
    result = stratFold(input_train_set, output_train_set, KNN_Learner, f1_score, average=mean)
    plot_learning_curve(result[0], result[1], result[2], title="f1_macro score learning curve")
    
    
def run_validation_curve(KNN_Learner, input_train_set, output_train_set, hyperparameter_values, weighting, hyperparameter, reverse, cross_validation_splitter, title):
    result_train, result_test = validation_curve(
        KNN_Learner, input_train_set, output_train_set.values.ravel(), param_name=hyperparameter, param_range=hyperparameter_values,
        scoring=weighting, verbose=1, cv=cross_validation_splitter, n_jobs=-1
    )
    print(result_train.mean(axis=1), result_test.mean(axis=1), hyperparameter_values)
    plot_complexity(result_train.mean(axis=1), result_test.mean(axis=1), hyperparameter_values, 
                    title='f1_weighted score', inverse_x=reverse)
    
    return result_train, result_test

def wine_dataset():
    target_feature = "class"
    mean = "weighted"
    weighting = "f1_weighted"
    hyperparameter = "n_neighbors"
    cross_validation_splitter = 10
    n_jobs = -1
    reverse = True
    
    
    np.random.seed(44)
    wine_dataset = pd.read_csv("wine_dataset.csv")
    print(wine_dataset.info())
    wine_dataset.head()
    
    target = wine_dataset[target_feature]
    wine_dataset = normalize_data(wine_dataset)
    wine_dataset[target_feature] = target
    
    in_sample, out_of_sample = create_stratified_data(target_feature, wine_dataset)
    
    #train_set = strat_train_set
    #test_set = strat_test_set
    
    output_train_set, input_train_set, output_test_set, input_test_set = prepare_data(in_sample, out_of_sample, target_feature)
    
    KNN_Learner = define_KNN(input_train_set, output_train_set)
    
    percent_match = KNN_predictions(KNN_Learner, input_train_set, output_train_set)
    
    result = cross_val_score(KNN_Learner, input_train_set, output_train_set.values.ravel(), scoring=weighting, cv=cross_validation_splitter)
    print(result.mean())
    
    compute_score(input_train_set, output_train_set, KNN_Learner, mean)
    
    KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                                 weights='distance')
    
    hyperparameter_values = [1,2,5,10,20,30,50,75,100,150,200]
    title='f1_weighted score'
    result_train, result_test = run_validation_curve(KNN_Learner, input_train_set, output_train_set, hyperparameter_values, weighting, hyperparameter, reverse, cross_validation_splitter, title)
    
    
    KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                                 weights='distance')

    hyperparameter_values = [1,2,5,10,20,30,50,75,100,150,200]
    result_train, result_test = run_validation_curve(KNN_Learner, input_train_set, output_train_set, hyperparameter_values, weighting, hyperparameter, reverse, cross_validation_splitter, title)
    
    
    optimal_KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                                 metric_params=None, n_jobs=None, n_neighbors=30, p=2,
                                 weights='uniform')

    compute_score(input_train_set, output_train_set, optimal_KNN_Learner, mean)



    # test with the test data
    optimal_KNN_Learner.fit(input_train_set, output_train_set.values.ravel())
    test_y_hat = optimal_KNN_Learner.predict(input_test_set)
    print(classification_report(output_test_set, test_y_hat,digits=5))
    print(confusion_matrix(output_test_set, test_y_hat))
    

def ufc_dataset():
    target_feature = "Winner"
    alpha = 0.005
    criterion = "entropy"
    mean = "macro"
    weighting = "f1_macro"
    hyperparameter = "n_neighbors"
    cross_validation_splitter = 10
    n_jobs = -1
    reverse = True
    
    
    np.random.seed(44)
    ufc_dataset = pd.read_csv("ufc_data.csv")
    print(ufc_dataset.info())
    ufc_dataset.head()
    
    # red is 1, blue is 0
    # drop the no_of_rounds because unknown in the beginning
    ufc_dataset.loc[ufc_dataset["Winner"] == "Red", "Winner"] = 1
    ufc_dataset.loc[ufc_dataset["Winner"] == "Blue", "Winner"] = 0
    ufc_dataset.drop(["no_of_rounds"], axis=1 ,inplace=True)
    # al zero
    ufc_dataset.drop(["B_draw"], axis=1 ,inplace=True)
    ufc_dataset.drop(["R_draw"], axis=1 ,inplace=True)
    
    ufc_dataset = normalize_data(ufc_dataset)
    
    in_sample, out_of_sample = create_stratified_data(target_feature, ufc_dataset)
    
    #train_set = strat_train_set
    #test_set = strat_test_set
    
    output_train_set, input_train_set, output_test_set, input_test_set = prepare_data(in_sample, out_of_sample, target_feature)
    
    KNN_Learner = define_KNN(input_train_set, output_train_set)
    
    percent_match = KNN_predictions(KNN_Learner, input_train_set, output_train_set)
    
    scores = cross_val_score(KNN_Learner, input_train_set, output_train_set.values.ravel(), scoring=weighting, cv=cross_validation_splitter)
    scores.mean()
    
    compute_score(input_train_set, output_train_set, KNN_Learner, mean)
    
    KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                             weights='uniform')

    hyperparameter_values = [2,5,10,20,30,50,75,100,150,200]
    title='f1_macro score'
    result_train, result_test = run_validation_curve(KNN_Learner, input_train_set, output_train_set, hyperparameter_values, weighting, hyperparameter, reverse, cross_validation_splitter, title)
    
    
    KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=100, p=2,
                             weights='distance')

    hyperparameter_values = [12,5,10,20,30,50,75,100,150,200]
    result_train, result_test = run_validation_curve(KNN_Learner, input_train_set, output_train_set, hyperparameter_values, weighting, hyperparameter, reverse, cross_validation_splitter, title)
    
    
    
    optimal_KNN_Learner = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                             metric_params=None, n_jobs=None, n_neighbors=2, p=2,
                             weights='distance')

    compute_score(input_train_set, output_train_set, optimal_KNN_Learner, mean)



    # test with the test data
    optimal_KNN_Learner.fit(input_train_set, output_train_set.values.ravel())
    test_y_hat = optimal_KNN_Learner.predict(input_test_set)
    print(classification_report(output_test_set, test_y_hat,digits=5))
    print(confusion_matrix(output_test_set, test_y_hat))
    
    
if __name__ == "__main__":
    wine_dataset()
    ufc_dataset()
